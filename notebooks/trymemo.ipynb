# %%
from datetime import datetime, timedelta
import pandas as pd

import pybcm
from matplotlib import pyplot as plt
from pybcm.config import BCMConfig
from pybcm.rest import RestClient
from pybcm.brick_data import BrickData
from pybcm.const import *

config = BCMConfig('../config/bcm.ini')
rc = RestClient(config)
bd = BrickData(config)

expire = timedelta(days=15)
# Out:
# Initializing <class 'pybcm.config.BCMConfig'> ../config/bcm.ini

# %%
from datetime import datetime, timedelta

ts = datetime.now()
te = datetime.now()
delta = te - ts
print(f"{delta.microseconds/1000}ms")
# Out:
# 0.073ms

# %%
from datetime import time, timedelta

def timeit(method):
    def timed(*args, **kw):
        ts = datetime.now()
        result = method(*args, **kw)
        te = datetime.now()
        delta = te - ts
        if 'log_time' in kw:
            name = kw.get('log_name', method.__name__.upper())
            kw['log_time'][name] = delta.seconds
        else:
            print(f"{method.__name__}, {delta.microseconds/1000:.3f} ms")     
        return result
    return timed

# %%
@timeit
def testit():
    print("some stuff")
    
testit()
testit()
testit()
# Out:
# some stuff
# testit, 0.080 ms
# some stuff
# testit, 0.034 ms
# some stuff
# testit, 0.033 ms

# %%
expire = timedelta(days=15)

def memoize_bd(function):
    """Used for wrapping functions in the BrickData class that take the arguments
        itemid, colorid, new_or_used=new_or_used, guide_type=guide_type
    """
    store_file = '/Users/Keith/Projects/pybcm_proj/resources/cache.hd5'

    def wrapper(itemid, colorid, new_or_used=None, guide_type=None, **kwargs):
        
        key = '_'.join([function.__name__, itemid, colorid, new_or_used, guide_type])
        with pd.HDFStore(store_file) as store:
            if key in store:
            # if key in hd5 and it's not too old
                print('Retrieving df from Store')
                df = store.get(key,)
                return df
            # return hd5 df
            else:
            # call the function and cache
                print('Calling function')
                df = function(itemid, colorid, new_or_used=new_or_used, guide_type=guide_type)
                store.put(key, df, format='table')
                return df

    return wrapper

# %%
@timeit
@memoize_bd
def get_price(itemid, colorid, new_or_used='N', guide_type='stock'):
    return bd.get_part_price_summary(itemid, colorid, new_or_used=new_or_used, guide_type=guide_type)

get_price('2420', '11', new_or_used='N', guide_type='stock')
get_price('2420', '12', new_or_used='N', guide_type='stock')
# Out:
# Retrieving df from Store
# wrapper, 16.367 ms
# Calling function
# wrapper, 892.480 ms
#   item_id itemtype color_id new_or_used currency_code  avg_price  max_price  \
# 0    2420     PART       12           N           USD     0.1156     6.9201
#
#    min_price  qty_avg_price  unit_quantity  total_quantity sold_or_stock  \
# 0      0.018         0.0987           9095          653409         stock
#
#           region
# 0  north_america

# %%
store_file = '/Users/Keith/Projects/pybcm_proj/resources/cache.hd5'

with pd.HDFStore(store_file) as store:
    print(store.keys())
# Out:
# ['/2420_86_N_stock', '/2420|86|N|stock', '/_242086Nstock', '/_2420_10_N_stock', '/_2420_11_N_stock', '/_2420_86_N_stock', '/__2420_86_N_stock', '/___main___2420_10_N_stock', '/___main___2420_11_N_stock', '/_get_price_2420_10_N_stock', '/_get_price_2420_11_N_stock', '/_|2420|86|N|stock', '/get_price_2420_10_N_stock', '/get_price_2420_11_N_stock', '/get_price_2420_12_N_stock']

# %%
import shelve

# %%
def memoize_rc(function):
    """Used for wrapping functions in the RestClient class that take the arguments
        itemid, itemtypeid, colorid, new_or_used, guide_type, vat, region
    """
    shelf_file = '/Users/Keith/Projects/pybcm_proj/resources/rccache'

    def wrapper(*args, **kwargs):
        
        key = '_'.join([function.__name__, *args, *kwargs])
        print(key)
        with shelve.open(shelf_file) as shelf:
            if key in shelf:
            # if key in shelf and it's not too old
                print('Retrieving df from Store')
                data = shelf[key]
                return data
            
            else:
            # call the function and cache
                print('Calling function')
                data = function(*args, **kwargs)
                shelf[key] = data
                return data

    return wrapper

# %%
@timeit
@memoize_rc
def get_item(itemid, itemtypeid):
    return rc.get_item(itemid, itemtypeid)

get_item('2420', 'PART')
get_item('2420', 'PART')
# Out:
# get_item_2420_PART
# Calling function
# wrapper, 611.714 ms
# get_item_2420_PART
# Retrieving df from Store
# wrapper, 1.338 ms
# {'no': '2420',
#  'name': 'Plate 2 x 2 Corner',
#  'type': 'PART',
#  'category_id': 26,
#  'image_url': '//img.bricklink.com/PL/2420.jpg',
#  'thumbnail_url': '//img.bricklink.com/P/4/2420.jpg',
#  'weight': '0.54',
#  'dim_x': '2.00',
#  'dim_y': '2.00',
#  'dim_z': '0.00',
#  'year_released': 1987,
#  'is_obsolete': False}

# %%
@timeit
@memoize_rc
def get_subsets(itemid, itemtype):
    return rc.get_subsets(itemid, itemtype)

get_subsets('9492-1', 'SET')
get_subsets('9492-1', 'SET')
# Out:
# get_subsets_9492-1_SET
# Retrieving df from Store
# wrapper, 3.518 ms
# get_subsets_9492-1_SET
# Retrieving df from Store
# wrapper, 2.307 ms
# [{'match_no': 0,
#   'entries': [{'item': {'no': '2357',
#      'name': 'Brick 2 x 2 Corner',
#      'type': 'PART',
#      'category_id': 5},
#     'color_id': 86,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '2420',
#      'name': 'Plate 2 x 2 Corner',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 85,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '2431',
#      'name': 'Tile 1 x 4',
#      'type': 'PART',
#      'category_id': 37},
#     'color_id': 86,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '2432',
#      'name': 'Tile, Modified 1 x 2 with Handle',
#      'type': 'PART',
#      'category_id': 38},
#     'color_id': 11,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '2445',
#      'name': 'Plate 2 x 12',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 11,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '2540',
#      'name': 'Plate, Modified 1 x 2 with Handle on Side - Free Ends',
#      'type': 'PART',
#      'category_id': 27},
#     'color_id': 86,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '2654',
#      'name': 'Plate, Round 2 x 2 with Rounded Bottom (Boat Stud)',
#      'type': 'PART',
#      'category_id': 28},
#     'color_id': 11,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '2817',
#      'name': 'Plate, Modified 2 x 2 with Pin Holes',
#      'type': 'PART',
#      'category_id': 27},
#     'color_id': 86,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3004',
#      'name': 'Brick 1 x 2',
#      'type': 'PART',
#      'category_id': 5},
#     'color_id': 86,
#     'quantity': 5,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3005',
#      'name': 'Brick 1 x 1',
#      'type': 'PART',
#      'category_id': 5},
#     'color_id': 85,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3020',
#      'name': 'Plate 2 x 4',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 85,
#     'quantity': 5,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3021',
#      'name': 'Plate 2 x 3',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 86,
#     'quantity': 8,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3022',
#      'name': 'Plate 2 x 2',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 1,
#     'quantity': 6,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3022',
#      'name': 'Plate 2 x 2',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 11,
#     'quantity': 12,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3022',
#      'name': 'Plate 2 x 2',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 86,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3023',
#      'name': 'Plate 1 x 2',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 3,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3023',
#      'name': 'Plate 1 x 2',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 85,
#     'quantity': 6,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3024',
#      'name': 'Plate 1 x 1',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 85,
#     'quantity': 6,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3032',
#      'name': 'Plate 4 x 6',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 85,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3034',
#      'name': 'Plate 2 x 8',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 11,
#     'quantity': 8,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '30373',
#      'name': 'Slope, Inverted 65 6 x 6 x 2 Quad with Cutouts',
#      'type': 'PART',
#      'category_id': 32},
#     'color_id': 85,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3039',
#      'name': 'Slope 45 2 x 2',
#      'type': 'PART',
#      'category_id': 31},
#     'color_id': 2,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3040',
#      'name': 'Slope 45 2 x 1',
#      'type': 'PART',
#      'category_id': 31},
#     'color_id': 86,
#     'quantity': 6,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '32000',
#      'name': 'Technic, Brick 1 x 2 with Holes',
#      'type': 'PART',
#      'category_id': 135},
#     'color_id': 5,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '32028',
#      'name': 'Plate, Modified 1 x 2 with Door Rail',
#      'type': 'PART',
#      'category_id': 27},
#     'color_id': 86,
#     'quantity': 6,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3300',
#      'name': 'Slope 33 2 x 2 Double',
#      'type': 'PART',
#      'category_id': 31},
#     'color_id': 85,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3460',
#      'name': 'Plate 1 x 8',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 11,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3623',
#      'name': 'Plate 1 x 3',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 86,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3665',
#      'name': 'Slope, Inverted 45 2 x 1',
#      'type': 'PART',
#      'category_id': 32},
#     'color_id': 86,
#     'quantity': 6,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3700',
#      'name': 'Technic, Brick 1 x 2 with Hole',
#      'type': 'PART',
#      'category_id': 135},
#     'color_id': 11,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3710',
#      'name': 'Plate 1 x 4',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 11,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3710',
#      'name': 'Plate 1 x 4',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 85,
#     'quantity': 10,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3710',
#      'name': 'Plate 1 x 4',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 86,
#     'quantity': 8,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3960',
#      'name': 'Dish 4 x 4 Inverted &#40;Radar&#41; with Solid Stud',
#      'type': 'PART',
#      'category_id': 116},
#     'color_id': 86,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '4032',
#      'name': 'Plate, Round 2 x 2 with Axle Hole',
#      'type': 'PART',
#      'category_id': 28},
#     'color_id': 1,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '4032',
#      'name': 'Plate, Round 2 x 2 with Axle Hole',
#      'type': 'PART',
#      'category_id': 28},
#     'color_id': 6,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '4073',
#      'name': 'Plate, Round 1 x 1 Straight Side',
#      'type': 'PART',
#      'category_id': 28},
#     'color_id': 11,
#     'quantity': 10,
#     'extra_quantity': 2,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '4073',
#      'name': 'Plate, Round 1 x 1 Straight Side',
#      'type': 'PART',
#      'category_id': 28},
#     'color_id': 17,
#     'quantity': 3,
#     'extra_quantity': 1,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '4162',
#      'name': 'Tile 1 x 8',
#      'type': 'PART',
#      'category_id': 37},
#     'color_id': 86,
#     'quantity': 8,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '4477',
#      'name': 'Plate 1 x 10',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 86,
#     'quantity': 12,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '30162',
#      'name': 'Minifigure, Utensil Binoculars Town',
#      'type': 'PART',
#      'category_id': 18},
#     'color_id': 86,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '4740',
#      'name': 'Dish 2 x 2 Inverted (Radar)',
#      'type': 'PART',
#      'category_id': 116},
#     'color_id': 11,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '32209',
#      'name': 'Technic, Axle 5.5 with Stop',
#      'type': 'PART',
#      'category_id': 134},
#     'color_id': 85,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '6178',
#      'name': 'Tile, Modified 6 x 12 with Studs on Edges',
#      'type': 'PART',
#      'category_id': 38},
#     'color_id': 11,
#     'quantity': 8,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '6541',
#      'name': 'Technic, Brick 1 x 1 with Hole',
#      'type': 'PART',
#      'category_id': 135},
#     'color_id': 3,
#     'quantity': 6,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '6558',
#      'name': 'Technic, Pin 3L with Friction Ridges Lengthwise',
#      'type': 'PART',
#      'category_id': 139},
#     'color_id': 7,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '6636',
#      'name': 'Tile 1 x 6',
#      'type': 'PART',
#      'category_id': 37},
#     'color_id': 86,
#     'quantity': 8,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3960px4',
#      'name': 'Dish 4 x 4 Inverted &#40;Radar&#41; with Solid Stud with Star Wars TIE Hatch Black and White Pattern',
#      'type': 'PART',
#      'category_id': 779},
#     'color_id': 85,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '33299',
#      'name': 'Technic, Liftarm 1 x 3 with 2 Axle Holes and Pin / Crank',
#      'type': 'PART',
#      'category_id': 137},
#     'color_id': 11,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '2412b',
#      'name': 'Tile, Modified 1 x 2 Grille with Bottom Groove / Lip',
#      'type': 'PART',
#      'category_id': 38},
#     'color_id': 17,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '2412b',
#      'name': 'Tile, Modified 1 x 2 Grille with Bottom Groove / Lip',
#      'type': 'PART',
#      'category_id': 38},
#     'color_id': 85,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '2429c01',
#      'name': 'Hinge Plate 1 x 4 Swivel Top / Base',
#      'type': 'PART',
#      'category_id': 22},
#     'color_id': 85,
#     'quantity': 8,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '43093',
#      'name': 'Technic, Axle Pin with Friction Ridges Lengthwise',
#      'type': 'PART',
#      'category_id': 134},
#     'color_id': 7,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3069b',
#      'name': 'Tile 1 x 2 with Groove',
#      'type': 'PART',
#      'category_id': 37},
#     'color_id': 86,
#     'quantity': 12,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '44728',
#      'name': 'Bracket 1 x 2 - 2 x 2',
#      'type': 'PART',
#      'category_id': 4},
#     'color_id': 11,
#     'quantity': 6,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '44570',
#      'name': 'Hinge Plate 3 x 4 Locking Dual 2 Finger',
#      'type': 'PART',
#      'category_id': 22},
#     'color_id': 85,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '44568',
#      'name': 'Hinge Plate 1 x 4 Locking Dual 1 Fingers on Side',
#      'type': 'PART',
#      'category_id': 22},
#     'color_id': 86,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '54200',
#      'name': 'Slope 30 1 x 1 x 2/3',
#      'type': 'PART',
#      'category_id': 31},
#     'color_id': 86,
#     'quantity': 9,
#     'extra_quantity': 1,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '51739',
#      'name': 'Wedge, Plate 2 x 4',
#      'type': 'PART',
#      'category_id': 583},
#     'color_id': 11,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '51739',
#      'name': 'Wedge, Plate 2 x 4',
#      'type': 'PART',
#      'category_id': 583},
#     'color_id': 86,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '54384',
#      'name': 'Wedge, Plate 6 x 3 Left',
#      'type': 'PART',
#      'category_id': 583},
#     'color_id': 11,
#     'quantity': 12,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '54383',
#      'name': 'Wedge, Plate 6 x 3 Right',
#      'type': 'PART',
#      'category_id': 583},
#     'color_id': 11,
#     'quantity': 12,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3747b',
#      'name': 'Slope, Inverted 33 3 x 2 with Connections between Studs',
#      'type': 'PART',
#      'category_id': 32},
#     'color_id': 85,
#     'quantity': 3,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3747b',
#      'name': 'Slope, Inverted 33 3 x 2 with Connections between Studs',
#      'type': 'PART',
#      'category_id': 32},
#     'color_id': 86,
#     'quantity': 8,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '58247',
#      'name': 'Minifigure, Weapon Gun, Blaster Short &#40;SW&#41;',
#      'type': 'PART',
#      'category_id': 19},
#     'color_id': 11,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '58176',
#      'name': 'Bar with Light Cover / Bionicle Barraki Eye',
#      'type': 'PART',
#      'category_id': 46},
#     'color_id': 17,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '4079b',
#      'name': 'Minifigure, Utensil Seat &#40;Chair&#41; 2 x 2 with Center Sprue Mark',
#      'type': 'PART',
#      'category_id': 18},
#     'color_id': 85,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '60478',
#      'name': 'Plate, Modified 1 x 2 with Handle on End - Closed Ends',
#      'type': 'PART',
#      'category_id': 27},
#     'color_id': 11,
#     'quantity': 8,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '60478',
#      'name': 'Plate, Modified 1 x 2 with Handle on End - Closed Ends',
#      'type': 'PART',
#      'category_id': 27},
#     'color_id': 86,
#     'quantity': 12,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '61184',
#      'name': 'Technic, Pin 1/2 with 2L Bar Extension (Flick Missile)',
#      'type': 'PART',
#      'category_id': 139},
#     'color_id': 86,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '60479',
#      'name': 'Plate 1 x 12',
#      'type': 'PART',
#      'category_id': 26},
#     'color_id': 11,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '60477',
#      'name': 'Slope 18 4 x 1',
#      'type': 'PART',
#      'category_id': 31},
#     'color_id': 85,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '63868',
#      'name': 'Plate, Modified 1 x 2 with Clip Horizontal on End',
#      'type': 'PART',
#      'category_id': 27},
#     'color_id': 86,
#     'quantity': 12,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '85984',
#      'name': 'Slope 30 1 x 2 x 2/3',
#      'type': 'PART',
#      'category_id': 31},
#     'color_id': 86,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '87609',
#      'name': 'Plate, Modified 2 x 6 x 2/3 with 4 Studs on Side',
#      'type': 'PART',
#      'category_id': 27},
#     'color_id': 11,
#     'quantity': 8,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '92950',
#      'name': 'Brick, Arch 1 x 6 Raised Arch',
#      'type': 'PART',
#      'category_id': 6},
#     'color_id': 85,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '92593',
#      'name': 'Plate, Modified 1 x 4 with 2 Studs without Groove',
#      'type': 'PART',
#      'category_id': 27},
#     'color_id': 85,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '60470b',
#      'name': 'Plate, Modified 1 x 2 with Clips Horizontal &#40;thick open O clips&#41;',
#      'type': 'PART',
#      'category_id': 27},
#     'color_id': 11,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '92582',
#      'name': 'Hinge Plate 2 x 2 Locking with 1 Finger on Top',
#      'type': 'PART',
#      'category_id': 22},
#     'color_id': 86,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '93273',
#      'name': 'Slope, Curved 4 x 1 Double No Studs',
#      'type': 'PART',
#      'category_id': 438},
#     'color_id': 86,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '44375b',
#      'name': 'Dish 6 x 6 Inverted (Radar) - Solid Studs',
#      'type': 'PART',
#      'category_id': 116},
#     'color_id': 86,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '50747pb06',
#      'name': 'Windscreen 6 x 6 x 3 Canopy Half Sphere with Dual 2 Fingers and SW Tie-Fighter Pattern',
#      'type': 'PART',
#      'category_id': 579},
#     'color_id': 13,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '4150pb086',
#      'name': 'Tile, Round 2 x 2 with Black SW Tie Fighter Pattern (9492)',
#      'type': 'PART',
#      'category_id': 812},
#     'color_id': 86,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': '3048c',
#      'name': 'Slope 45 2 x 1 Triple with Inside Bar',
#      'type': 'PART',
#      'category_id': 31},
#     'color_id': 85,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': 'sw0268a',
#      'name': 'TIE Fighter Pilot (Patterned Head)',
#      'type': 'MINIFIG',
#      'category_id': 65},
#     'color_id': 0,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': 'sw0374',
#      'name': 'Death Star Trooper',
#      'type': 'MINIFIG',
#      'category_id': 65},
#     'color_id': 0,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': 'sw0375',
#      'name': 'R5-J2',
#      'type': 'MINIFIG',
#      'category_id': 65},
#     'color_id': 0,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 0,
#   'entries': [{'item': {'no': 'sw0376',
#      'name': 'Imperial Officer &#40;Captain / Commandant / Commander&#41; - Two Code Cylinders, Cavalry Kepi',
#      'type': 'MINIFIG',
#      'category_id': 65},
#     'color_id': 0,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False}]},
#  {'match_no': 1,
#   'entries': [{'item': {'no': '42445',
#      'name': 'Bar  12L with 1 x 2 Plate End Solid Studs and 1 x 1 Round Plate End',
#      'type': 'PART',
#      'category_id': 46},
#     'color_id': 86,
#     'quantity': 12,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False},
#    {'item': {'no': '99784',
#      'name': 'Bar  12L with 1 x 2 Plate End Hollow Studs and 1 x 1 Round Plate End',
#      'type': 'PART',
#      'category_id': 46},
#     'color_id': 86,
#     'quantity': 12,
#     'extra_quantity': 0,
#     'is_alternate': True,
#     'is_counterpart': False}]},
#  {'match_no': 2,
#   'entries': [{'item': {'no': '3794a',
#      'name': 'Plate, Modified 1 x 2 with 1 Stud without Groove &#40;Jumper&#41;',
#      'type': 'PART',
#      'category_id': 27},
#     'color_id': 86,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False},
#    {'item': {'no': '3794b',
#      'name': 'Plate, Modified 1 x 2 with 1 Stud with Groove (Jumper)',
#      'type': 'PART',
#      'category_id': 27},
#     'color_id': 86,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': True,
#     'is_counterpart': False}]},
#  {'match_no': 3,
#   'entries': [{'item': {'no': '3794a',
#      'name': 'Plate, Modified 1 x 2 with 1 Stud without Groove &#40;Jumper&#41;',
#      'type': 'PART',
#      'category_id': 27},
#     'color_id': 11,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False},
#    {'item': {'no': '3794b',
#      'name': 'Plate, Modified 1 x 2 with 1 Stud with Groove (Jumper)',
#      'type': 'PART',
#      'category_id': 27},
#     'color_id': 11,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': True,
#     'is_counterpart': False}]},
#  {'match_no': 4,
#   'entries': [{'item': {'no': '3794a',
#      'name': 'Plate, Modified 1 x 2 with 1 Stud without Groove &#40;Jumper&#41;',
#      'type': 'PART',
#      'category_id': 27},
#     'color_id': 85,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False},
#    {'item': {'no': '3794b',
#      'name': 'Plate, Modified 1 x 2 with 1 Stud with Groove (Jumper)',
#      'type': 'PART',
#      'category_id': 27},
#     'color_id': 85,
#     'quantity': 4,
#     'extra_quantity': 0,
#     'is_alternate': True,
#     'is_counterpart': False}]},
#  {'match_no': 5,
#   'entries': [{'item': {'no': '3049b',
#      'name': 'Slope 45 2 x 1 Double / Inverted - without Bottom Tube or Bottom Stud Holder',
#      'type': 'PART',
#      'category_id': 31},
#     'color_id': 86,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': False,
#     'is_counterpart': False},
#    {'item': {'no': '3049c',
#      'name': 'Slope 45 2 x 1 Double / Inverted - with Bottom Stud Holder',
#      'type': 'PART',
#      'category_id': 31},
#     'color_id': 86,
#     'quantity': 2,
#     'extra_quantity': 0,
#     'is_alternate': True,
#     'is_counterpart': False}]},
#  {'match_no': 6,
#   'entries': [{'item': {'no': '3626cpb0680',
#      'name': 'Minifigure, Head Dual Sided Glasses with Black Goggles, Gray Chin Strap / Stern Eyebrows, Gray Chin Strap Pattern - Hollow Stud',
#      'type': 'PART',
#      'category_id': 238},
#     'color_id': 90,
#     'quantity': 1,
#     'extra_quantity': 0,
#     'is_alternate': True,
#     'is_counterpart': False}]}]

# %%
def try_args(*args, **kwargs):
    key = '_'.join([ *args, *kwargs])
    print(f"{', '.join([*args, *kwargs.values()])}")
    print(key)
try_args('argw1', 'arg2', arg3='arg3text')
# Out:
# argw1, arg2, arg3text
# argw1_arg2_arg3

# %%
rc.get_price_guide('3006', 'PART', '10', new_or_used = 'U', guide_type='stock')
# Out:
# {'item': {'no': '3006', 'type': 'PART'},
#  'new_or_used': 'U',
#  'currency_code': 'USD',
#  'min_price': '0.0100',
#  'max_price': '28.5700',
#  'avg_price': '0.5648',
#  'qty_avg_price': '0.6943',
#  'unit_quantity': 1763,
#  'total_quantity': 8210,
#  'price_detail': [{'quantity': 134,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 134},
#   {'quantity': 109,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 109},
#   {'quantity': 97,
#    'unit_price': '0.7500',
#    'shipping_available': True,
#    'qunatity': 97},
#   {'quantity': 93,
#    'unit_price': '1.8525',
#    'shipping_available': True,
#    'qunatity': 93},
#   {'quantity': 75,
#    'unit_price': '0.2610',
#    'shipping_available': True,
#    'qunatity': 75},
#   {'quantity': 74,
#    'unit_price': '0.8320',
#    'shipping_available': True,
#    'qunatity': 74},
#   {'quantity': 64,
#    'unit_price': '1.1000',
#    'shipping_available': True,
#    'qunatity': 64},
#   {'quantity': 62,
#    'unit_price': '1.8525',
#    'shipping_available': True,
#    'qunatity': 62},
#   {'quantity': 60,
#    'unit_price': '0.5500',
#    'shipping_available': True,
#    'qunatity': 60},
#   {'quantity': 60,
#    'unit_price': '0.6000',
#    'shipping_available': True,
#    'qunatity': 60},
#   {'quantity': 60,
#    'unit_price': '0.1600',
#    'shipping_available': True,
#    'qunatity': 60},
#   {'quantity': 58,
#    'unit_price': '0.7200',
#    'shipping_available': True,
#    'qunatity': 58},
#   {'quantity': 51,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 51},
#   {'quantity': 51,
#    'unit_price': '1.5000',
#    'shipping_available': True,
#    'qunatity': 51},
#   {'quantity': 46,
#    'unit_price': '2.6300',
#    'shipping_available': True,
#    'qunatity': 46},
#   {'quantity': 44,
#    'unit_price': '2.8025',
#    'shipping_available': True,
#    'qunatity': 44},
#   {'quantity': 42,
#    'unit_price': '0.4090',
#    'shipping_available': True,
#    'qunatity': 42},
#   {'quantity': 41,
#    'unit_price': '1.0800',
#    'shipping_available': True,
#    'qunatity': 41},
#   {'quantity': 40,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 40},
#   {'quantity': 38,
#    'unit_price': '0.4500',
#    'shipping_available': True,
#    'qunatity': 38},
#   {'quantity': 35,
#    'unit_price': '0.3200',
#    'shipping_available': True,
#    'qunatity': 35},
#   {'quantity': 34,
#    'unit_price': '3.2800',
#    'shipping_available': True,
#    'qunatity': 34},
#   {'quantity': 34,
#    'unit_price': '3.2800',
#    'shipping_available': True,
#    'qunatity': 34},
#   {'quantity': 33,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 33},
#   {'quantity': 31,
#    'unit_price': '0.9600',
#    'shipping_available': True,
#    'qunatity': 31},
#   {'quantity': 31,
#    'unit_price': '0.1414',
#    'shipping_available': True,
#    'qunatity': 31},
#   {'quantity': 30,
#    'unit_price': '0.3200',
#    'shipping_available': True,
#    'qunatity': 30},
#   {'quantity': 30,
#    'unit_price': '0.3900',
#    'shipping_available': True,
#    'qunatity': 30},
#   {'quantity': 29,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 29},
#   {'quantity': 28,
#    'unit_price': '0.8111',
#    'shipping_available': True,
#    'qunatity': 28},
#   {'quantity': 27,
#    'unit_price': '0.7500',
#    'shipping_available': True,
#    'qunatity': 27},
#   {'quantity': 26,
#    'unit_price': '0.3300',
#    'shipping_available': True,
#    'qunatity': 26},
#   {'quantity': 26,
#    'unit_price': '2.0000',
#    'shipping_available': True,
#    'qunatity': 26},
#   {'quantity': 25,
#    'unit_price': '2.3450',
#    'shipping_available': True,
#    'qunatity': 25},
#   {'quantity': 24,
#    'unit_price': '2.9900',
#    'shipping_available': True,
#    'qunatity': 24},
#   {'quantity': 24,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 24},
#   {'quantity': 24,
#    'unit_price': '1.0520',
#    'shipping_available': True,
#    'qunatity': 24},
#   {'quantity': 24,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 24},
#   {'quantity': 23,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 23},
#   {'quantity': 23,
#    'unit_price': '0.6800',
#    'shipping_available': True,
#    'qunatity': 23},
#   {'quantity': 22,
#    'unit_price': '0.2700',
#    'shipping_available': True,
#    'qunatity': 22},
#   {'quantity': 22,
#    'unit_price': '0.7500',
#    'shipping_available': True,
#    'qunatity': 22},
#   {'quantity': 22,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 22},
#   {'quantity': 21,
#    'unit_price': '1.2500',
#    'shipping_available': True,
#    'qunatity': 21},
#   {'quantity': 21,
#    'unit_price': '0.9140',
#    'shipping_available': True,
#    'qunatity': 21},
#   {'quantity': 21,
#    'unit_price': '3.7525',
#    'shipping_available': True,
#    'qunatity': 21},
#   {'quantity': 21,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 21},
#   {'quantity': 20,
#    'unit_price': '1.8525',
#    'shipping_available': True,
#    'qunatity': 20},
#   {'quantity': 20,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 20},
#   {'quantity': 20,
#    'unit_price': '1.5000',
#    'shipping_available': True,
#    'qunatity': 20},
#   {'quantity': 20,
#    'unit_price': '3.9300',
#    'shipping_available': True,
#    'qunatity': 20},
#   {'quantity': 20,
#    'unit_price': '0.2000',
#    'shipping_available': True,
#    'qunatity': 20},
#   {'quantity': 19,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 19},
#   {'quantity': 19,
#    'unit_price': '2.0000',
#    'shipping_available': True,
#    'qunatity': 19},
#   {'quantity': 19,
#    'unit_price': '0.9000',
#    'shipping_available': True,
#    'qunatity': 19},
#   {'quantity': 19,
#    'unit_price': '0.3300',
#    'shipping_available': True,
#    'qunatity': 19},
#   {'quantity': 19,
#    'unit_price': '0.2550',
#    'shipping_available': True,
#    'qunatity': 19},
#   {'quantity': 19,
#    'unit_price': '0.3600',
#    'shipping_available': True,
#    'qunatity': 19},
#   {'quantity': 19,
#    'unit_price': '2.1200',
#    'shipping_available': True,
#    'qunatity': 19},
#   {'quantity': 19,
#    'unit_price': '0.2660',
#    'shipping_available': True,
#    'qunatity': 19},
#   {'quantity': 19,
#    'unit_price': '1.3400',
#    'shipping_available': True,
#    'qunatity': 19},
#   {'quantity': 19,
#    'unit_price': '0.8280',
#    'shipping_available': True,
#    'qunatity': 19},
#   {'quantity': 19,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 19},
#   {'quantity': 19,
#    'unit_price': '0.2100',
#    'shipping_available': True,
#    'qunatity': 19},
#   {'quantity': 18,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 18},
#   {'quantity': 18,
#    'unit_price': '0.2456',
#    'shipping_available': True,
#    'qunatity': 18},
#   {'quantity': 18,
#    'unit_price': '0.3349',
#    'shipping_available': True,
#    'qunatity': 18},
#   {'quantity': 18,
#    'unit_price': '0.4197',
#    'shipping_available': True,
#    'qunatity': 18},
#   {'quantity': 18,
#    'unit_price': '1.3400',
#    'shipping_available': True,
#    'qunatity': 18},
#   {'quantity': 18,
#    'unit_price': '0.3200',
#    'shipping_available': True,
#    'qunatity': 18},
#   {'quantity': 18,
#    'unit_price': '3.0000',
#    'shipping_available': True,
#    'qunatity': 18},
#   {'quantity': 18,
#    'unit_price': '0.3900',
#    'shipping_available': True,
#    'qunatity': 18},
#   {'quantity': 17,
#    'unit_price': '1.5000',
#    'shipping_available': True,
#    'qunatity': 17},
#   {'quantity': 17,
#    'unit_price': '0.4600',
#    'shipping_available': True,
#    'qunatity': 17},
#   {'quantity': 17,
#    'unit_price': '2.1050',
#    'shipping_available': True,
#    'qunatity': 17},
#   {'quantity': 17,
#    'unit_price': '0.2977',
#    'shipping_available': True,
#    'qunatity': 17},
#   {'quantity': 17,
#    'unit_price': '0.1520',
#    'shipping_available': True,
#    'qunatity': 17},
#   {'quantity': 17,
#    'unit_price': '0.4465',
#    'shipping_available': True,
#    'qunatity': 17},
#   {'quantity': 17,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 17},
#   {'quantity': 16,
#    'unit_price': '1.3030',
#    'shipping_available': True,
#    'qunatity': 16},
#   {'quantity': 16,
#    'unit_price': '0.3510',
#    'shipping_available': True,
#    'qunatity': 16},
#   {'quantity': 16,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 16},
#   {'quantity': 16,
#    'unit_price': '0.3200',
#    'shipping_available': True,
#    'qunatity': 16},
#   {'quantity': 16,
#    'unit_price': '1.2800',
#    'shipping_available': True,
#    'qunatity': 16},
#   {'quantity': 16,
#    'unit_price': '1.5000',
#    'shipping_available': True,
#    'qunatity': 16},
#   {'quantity': 16,
#    'unit_price': '0.1900',
#    'shipping_available': True,
#    'qunatity': 16},
#   {'quantity': 16,
#    'unit_price': '0.2580',
#    'shipping_available': True,
#    'qunatity': 16},
#   {'quantity': 16,
#    'unit_price': '0.4000',
#    'shipping_available': True,
#    'qunatity': 16},
#   {'quantity': 15,
#    'unit_price': '0.2100',
#    'shipping_available': True,
#    'qunatity': 15},
#   {'quantity': 15,
#    'unit_price': '0.2700',
#    'shipping_available': True,
#    'qunatity': 15},
#   {'quantity': 15,
#    'unit_price': '1.2500',
#    'shipping_available': True,
#    'qunatity': 15},
#   {'quantity': 15,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 15},
#   {'quantity': 15,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 15},
#   {'quantity': 15,
#    'unit_price': '0.2880',
#    'shipping_available': True,
#    'qunatity': 15},
#   {'quantity': 15,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 15},
#   {'quantity': 15,
#    'unit_price': '1.8525',
#    'shipping_available': True,
#    'qunatity': 15},
#   {'quantity': 15,
#    'unit_price': '0.2200',
#    'shipping_available': True,
#    'qunatity': 15},
#   {'quantity': 15,
#    'unit_price': '0.2700',
#    'shipping_available': True,
#    'qunatity': 15},
#   {'quantity': 14,
#    'unit_price': '1.0000',
#    'shipping_available': True,
#    'qunatity': 14},
#   {'quantity': 14,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 14},
#   {'quantity': 14,
#    'unit_price': '2.3450',
#    'shipping_available': True,
#    'qunatity': 14},
#   {'quantity': 14,
#    'unit_price': '0.2200',
#    'shipping_available': True,
#    'qunatity': 14},
#   {'quantity': 14,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 14},
#   {'quantity': 14,
#    'unit_price': '0.5900',
#    'shipping_available': True,
#    'qunatity': 14},
#   {'quantity': 14,
#    'unit_price': '0.9000',
#    'shipping_available': True,
#    'qunatity': 14},
#   {'quantity': 14,
#    'unit_price': '0.1032',
#    'shipping_available': True,
#    'qunatity': 14},
#   {'quantity': 14,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 14},
#   {'quantity': 14,
#    'unit_price': '0.4600',
#    'shipping_available': True,
#    'qunatity': 14},
#   {'quantity': 14,
#    'unit_price': '1.0000',
#    'shipping_available': True,
#    'qunatity': 14},
#   {'quantity': 13,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 13},
#   {'quantity': 13,
#    'unit_price': '0.2000',
#    'shipping_available': True,
#    'qunatity': 13},
#   {'quantity': 13,
#    'unit_price': '0.2300',
#    'shipping_available': True,
#    'qunatity': 13},
#   {'quantity': 13,
#    'unit_price': '1.2900',
#    'shipping_available': True,
#    'qunatity': 13},
#   {'quantity': 13,
#    'unit_price': '3.3500',
#    'shipping_available': True,
#    'qunatity': 13},
#   {'quantity': 13,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 13},
#   {'quantity': 13,
#    'unit_price': '0.3125',
#    'shipping_available': True,
#    'qunatity': 13},
#   {'quantity': 13,
#    'unit_price': '0.1711',
#    'shipping_available': True,
#    'qunatity': 13},
#   {'quantity': 13,
#    'unit_price': '0.2400',
#    'shipping_available': True,
#    'qunatity': 13},
#   {'quantity': 13,
#    'unit_price': '0.3600',
#    'shipping_available': True,
#    'qunatity': 13},
#   {'quantity': 13,
#    'unit_price': '0.3280',
#    'shipping_available': True,
#    'qunatity': 13},
#   {'quantity': 12,
#    'unit_price': '0.2753',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '0.4093',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '0.7190',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '0.2400',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '0.1550',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '0.8500',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '1.1810',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '0.2700',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '0.2349',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '0.1200',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '0.4000',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '1.2800',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '1.4900',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '0.2200',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 12,
#    'unit_price': '0.2560',
#    'shipping_available': True,
#    'qunatity': 12},
#   {'quantity': 11,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '1.3300',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.4700',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.6000',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.6750',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.7290',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.2800',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '3.5000',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.2000',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '1.2500',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.1233',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.3300',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.2000',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.2700',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.1500',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.4500',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.2700',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '0.2800',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 11,
#    'unit_price': '2.3655',
#    'shipping_available': True,
#    'qunatity': 11},
#   {'quantity': 10,
#    'unit_price': '0.4410',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '9.4525',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.3600',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.2720',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.3400',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.3360',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '1.1180',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.2000',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.7630',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.7980',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.2250',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '1.1600',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.2700',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.4100',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.7900',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.3300',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.3900',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.2009',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '1.3700',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.2530',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 10,
#    'unit_price': '0.5900',
#    'shipping_available': True,
#    'qunatity': 10},
#   {'quantity': 9,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.4500',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '4.5100',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.3200',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.4200',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.3300',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.2000',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.3400',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.0372',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.8930',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.2604',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.1863',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.3100',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.1720',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '1.6200',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '1.0680',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '1.2500',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.1550',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.1400',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.4152',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.4000',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.6510',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.3050',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.1800',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.3200',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.2880',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.8500',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 9,
#    'unit_price': '0.2090',
#    'shipping_available': True,
#    'qunatity': 9},
#   {'quantity': 8,
#    'unit_price': '0.5310',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '1.8720',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.4000',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '1.1340',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.4200',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '1.4808',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.0737',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.9760',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.2975',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.1116',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.0380',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.4040',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '1.2000',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.2700',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.2300',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '1.3400',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '1.8200',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.3178',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.6500',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.6500',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.1804',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.2240',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '1.0000',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.2000',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.1740',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.1191',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.3400',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '1.4100',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.4100',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.3200',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.4000',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.2480',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.2772',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '4.5800',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.1935',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.4000',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.4000',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.1500',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 8,
#    'unit_price': '0.2900',
#    'shipping_available': True,
#    'qunatity': 8},
#   {'quantity': 7,
#    'unit_price': '0.2040',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.3700',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '1.0000',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2232',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '1.6500',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.4000',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2640',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.3300',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.3900',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.5300',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2200',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.1517',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2200',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2230',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2700',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.3200',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2700',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '3.6600',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '1.0300',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.1860',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.0600',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.8800',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2640',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.4100',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.3300',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2100',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '3.3500',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.0100',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.0100',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.1530',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.6630',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.4000',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2200',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.0380',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.1339',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2977',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.3850',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.9500',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2700',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.3600',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2140',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '1.8000',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.1800',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '2.2500',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.1611',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.1500',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.2300',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '1.3500',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.1500',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 7,
#    'unit_price': '0.3200',
#    'shipping_available': True,
#    'qunatity': 7},
#   {'quantity': 6,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2831',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2100',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.1200',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.1116',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.1637',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2750',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2400',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2400',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2158',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2890',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2063',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2700',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.4000',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.1480',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.1200',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.1339',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2800',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.6380',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.3230',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.3430',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.3200',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '11.3900',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '1.3400',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '2.0100',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.3200',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2900',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.7490',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2381',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2142',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2000',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2270',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2480',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2100',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.1500',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.8800',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '1.1500',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '1.3900',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2900',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.4000',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.4000',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.3910',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '11.8200',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2480',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.1600',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2800',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.4000',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.7069',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2084',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2000',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.4500',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.6460',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 6,
#    'unit_price': '0.2040',
#    'shipping_available': True,
#    'qunatity': 6},
#   {'quantity': 5,
#    'unit_price': '0.1870',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.1190',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.6353',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2300',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.1000',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2604',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '4.0200',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.9900',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '1.4000',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3830',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '2.6500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '2.6500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2225',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3300',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2800',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2640',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.1550',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2100',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.0867',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.0990',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.1300',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2200',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2400',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3300',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.7780',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.7500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.0595',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.8855',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3440',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.7300',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2450',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '1.6436',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2400',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2240',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3900',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '1.6100',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '2.0100',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3700',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3550',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.1910',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '1.2000',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.1488',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.1300',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.1600',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2200',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.0765',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.9400',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3190',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2728',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3401',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3207',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2900',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2230',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2510',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3120',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3100',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.1400',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2400',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2200',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3646',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.1500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.1637',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3349',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.1935',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.3090',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.1600',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.7500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.2100',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 5,
#    'unit_price': '0.1637',
#    'shipping_available': True,
#    'qunatity': 5},
#   {'quantity': 4,
#    'unit_price': '0.3850',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.2084',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.2000',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.2034',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.3200',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.4600',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.1360',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.6300',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.2180',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.2604',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.2800',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.2010',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.2977',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.2200',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.4000',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.4400',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.2370',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '1.6000',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.1500',
#    'shipping_available': True,
#    'qunatity': 4},
#   {'quantity': 4,
#    'unit_price': '0.9300',
# ...
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3800',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3900',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2100',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3320',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.8000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3070',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2700',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1600',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.9000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1816',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1900',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.4100',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2300',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.4300',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2900',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '1.0000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1448',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2740',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.0700',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1900',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.8700',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1800',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2720',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3400',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2125',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1200',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1600',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '2.0000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.4900',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2480',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1103',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.6000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3400',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2456',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.5900',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3100',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.5581',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2456',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2232',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '1.3655',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1563',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.4700',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2220',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1820',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1520',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.0982',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.0400',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.0800',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3200',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.7900',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1860',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1339',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3600',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2200',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2232',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.6700',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '1.8170',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3260',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1600',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3100',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1600',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3200',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1660',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '3.8700',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '2.6300',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '2.7700',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2300',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2200',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3300',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1572',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2800',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.6400',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1900',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1770',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2730',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2977',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.0800',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3200',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2400',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3340',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2232',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1100',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.0200',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1580',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2800',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1875',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '1.4100',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3700',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2480',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2250',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1440',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '1.2320',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3310',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2220',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.4100',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1600',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2604',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '1.3400',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '2.0100',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '1.2980',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2520',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2050',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2100',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2381',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1414',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2700',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1900',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1800',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2600',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2068',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '1.0232',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3060',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2295',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.4500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2158',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.9500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2900',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2170',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2300',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.5026',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '1.4000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3100',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2700',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1810',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.7000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1980',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.6368',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1230',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2250',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '4.0000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.3500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.5000',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.1500',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2110',
#    'shipping_available': True,
#    'qunatity': 2},
#   {'quantity': 2,
#    'unit_price': '0.2025',
#    'shipping_available': True,
#    'qunatity': 2},
#   ...]}
